# %%
import sqlite3
import pandas as pd

# %%
df = pd.read_csv('chat_messages.csv')
df
# Out:
#                                                      text  handle_id  \
# 0       Not bothersome at all there’s nothing interest...        1.0
# 1                                                     lol        1.0
# 2                                 And I also care about u        1.0
# 3                                                     NaN        1.0
# 4                                                    oops        1.0
# ...                                                   ...        ...
# 373711                                      Liked “4:30?”      300.0
# 373712                                      Liked “4:30?”      293.0
# 373713                                    What about 5:30      293.0
# 373714                            Loved “What about 5:30”      299.0
# 373715      Omw to practice and packed clothes for after       493.0
#
#               date  message_date            timestamp  month    year  is_sent  \
# ...
